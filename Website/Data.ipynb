# %%
import os.path
import pickle

with open(os.path.abspath(os.path.join("..", "Violet", "pokeapi", "pokeapi_stats.pkl")), 'rb') as pklFile:
    data = pickle.load(pklFile)

data[2]
# ìmport pickle

# with open(syst, 'rb') as f:
#   data = pickle.load(f)
# Out:
# {'name': {'LANG_GER': 'Bisaknosp', 'LANG_EN': 'Ivysaur'},
#  'egg_group_0': 'Monster',
#  'egg_group_1': 'Pflanze',
#  'gender_ratio': 32,
#  'capture_rate': 45,
#  'base_happiness': 70,
#  'egg_cycles': 20,
#  'color_and_flip': {'flip': 0, 'color': 'Grün'},
#  'shape': 'Quadruped',
#  'growth_rate': 'medium-slow',
#  'evolutions': {'POKEMON_BISAFLOR': {'trigger': 'Level_Up',
#    'argument': 32,
#    'baby_trigger_item': None}},
#  'dex_entry': {'LANG_GER': 'Sobald die Knospe auf seinem Rücken ein süßes Aroma abgibt, steht die Blüte kurz bevor.',
#   'LANG_EN': 'When the bud on its back starts swelling, a sweet aroma wafts to indicate the flower’s coming bloom.'},
#  'genus': {'LANG_GER': 'Samen', 'LANG_EN': 'Seed'},
#  'height': 10,
#  'weight': 130,
#  'exp_yield': 142,
#  'hidden_ability': 'Chlorophyll',
#  'ability_0': 'Notdünger',
#  'ability_1': None,
#  'basestats': {'hp': 60,
#   'attack': 62,
#   'defense': 63,
#   'special-attack': 80,
#   'special-defense': 80,
# ...
